# %% [markdown]
# # Phase IV — Anode durability + closed-loop CSTR

# %%
from models.closed_loop import PhaseIVClosedLoop
from models.anode import AnodeKinetics, DSA_IRO2_TA2O5

anode = AnodeKinetics(material=DSA_IRO2_TA2O5, pH=14, electrolyte_type="alkaline")
loop = PhaseIVClosedLoop(anode=anode)
res = loop.simulate(duration_hr=100, dt_hr=1.0)
print(res.summary())
print("Flags sample:", res.flags[:5])
