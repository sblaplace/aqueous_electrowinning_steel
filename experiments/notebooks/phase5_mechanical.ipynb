# %% [markdown]
# # Phase V — Mechanical properties
# Hall-Petch + Ni SS + C dispersion → YS/UTS/HV/grade

# %%
from models.co_deposition import build_phase3_model
from models.mechanical_properties import build_mechanical_model_from_phase3_result

p3 = build_phase3_model().run_at_current(100)
print(p3)
from models.mechanical_properties import MechanicalPropertiesModel
mech = MechanicalPropertiesModel()
res = mech.predict(j_avg_mA_cm2=100, j_peak_mA_cm2=200, duty_cycle=0.5, waveform="pre", ni_wt_percent=2.0, carbon_wt_percent=0.8, current_efficiency_percent=93)
print(res.summary())
